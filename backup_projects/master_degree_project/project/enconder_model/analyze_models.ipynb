# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Dibujar modelos

# %%
os.chdir('..')
def root_mean_squared_error(y_true, y_pred):
    rmse = tf.math.sqrt(tf.math.reduce_mean(tf.square(y_pred-y_true)))
    return rmse

# %%
modelo = tf.keras.models.load_model('enconder_model/tunning_save/best_model_0.7.h5', 
                                    custom_objects={'root_mean_squared_error': root_mean_squared_error})

# %%
modelo.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 24, 1)]      0           []
#
#  layer_normalization_2 (LayerNo  (None, 24, 1)       2           ['input_2[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 24, 1)       897         ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 24, 1)        0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 24, 1)       0           ['dropout_3[0][0]',
#  mbda)                                                            'input_2[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 24, 1)       2           ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 24, 1)        2           ['layer_normalization_3[0][0]']
#
#  dropout_4 (Dropout)            (None, 24, 1)        0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 24, 1)        2           ['dropout_4[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 24, 1)       0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 24)          0           ['tf.__operators__.add_3[0][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 32)           800         ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  dropout_5 (Dropout)            (None, 32)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 1)            33          ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 1,738
# Trainable params: 1,738
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
dot_img_file = 'enconder_model/bases_model/base.png'
tf.keras.utils.plot_model(modelo, to_file=dot_img_file, show_shapes=True)

# %%
pd.read_csv('enconder_model/bases_model/df_results_bases.csv')
# Out:
#    Unnamed: 0  trainig_size        model  type  training_time  \
# 0           0           0.7  transformer  base     271.141982
# 1           1           0.8  transformer  base     301.630089
# 2           2           0.9  transformer  base     139.830219
#
#    prediction_time  rmse_trainig  rmse_validation  rmse_test   mean_MAE  \
# 0         2.467109      0.004185         0.006096   0.006988  12.678758
# 1         2.234354      0.004303         0.007743   0.007017  12.897844
# 2         1.147879      0.004751         0.004712   0.009804  18.347335
#
#          r2  mean_RMSE  mean_MAPE
# 0  0.964162  30.432660   5.697695
# 1  0.964049  30.481191   5.776222
# 2  0.952890  39.530464   7.343361

# %%
pd.read_csv('enconder_model/tunning_save/df_results_best.csv')
# Out:
#    Unnamed: 0.1  Unnamed: 0  trainig_size        model     type  \
# 0             0           0           0.7  transformer  tunning
# 1             1           1           0.8  transformer  tunning
# 2             2           2           0.9  transformer  tunning
#
#    training_time  prediction_time  rmse_trainig  rmse_validation  rmse_test  \
# 0     256.998935         4.319690      0.004304         0.006191   0.007225
# 1     243.136340         2.414063      0.004216         0.007718   0.006872
# 2     281.724012         1.630778      0.004680         0.004425   0.009348
#
#     mean_MAE        r2  mean_RMSE  mean_MAPE  \
# 0  13.546108  0.962736  31.032234   5.899985
# 1  12.075787  0.964701  30.203517   5.314426
# 2  16.367750  0.953912  39.099295   6.595585
#
#                                         architecture
# 0  [[(64, 'head_size'), (2, 'num_heads'), (1, 'ff...
# 1  [[(32, 'head_size'), (2, 'num_heads'), (3, 'ff...
# 2  [[(128, 'head_size'), (1, 'num_heads'), (3, 'f...
